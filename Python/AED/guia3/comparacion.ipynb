# %%
import random
import time
import matplotlib.pyplot as plt

# %% [markdown]
# **Metodo Quicksort**

# %%
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[0]
        less = [x for x in arr[1:] if x <= pivot]
        greater = [x for x in arr[1:] if x > pivot]
        return quicksort(less) + [pivot] + quicksort(greater)

# %% [markdown]
# **Metodo Burbuja, el mas eficiente**

# %%
def ordenamiento_burbuja_optimizado2(lista):
    n = len(lista)
    intercambio = True
    iteracion = 0

    while (intercambio):
        intercambio = False
        for i in range(n - iteracion - 1):
            if (lista[i] > lista[i+1]):
                temp1 = lista[i]
                lista[i] = lista[i+1]
                lista[i+1] = temp1
                #lista[j], lista[j+1] = lista[j+1], lista[j]
                intercambio = True
        iteracion += 1
    #print("Numero de iteracion: ", iteracion)
    return lista

# %% [markdown]
# **Metodo Insercion**

# %%
def ordenamiento_insercion(A):
    n = len(A)

    for i in range(n):
        posicion = i
        aux = A[i]
        while (posicion > 0) and (A[posicion-1] > aux):
            A[posicion] = A[posicion-1]
            posicion = posicion - 1
        A[posicion] = aux
    return A

# %% [markdown]
# **Impresion de listas ordenadas**

# %%
numero = 300
A = []
for i in range(numero):
    A.append(random.randint(0, numero))

print("Lista original: ", A)
print("Lista ordenada por Quicksort")
print(quicksort(A))
print("Lista ordenada por Insercion")
print(ordenamiento_insercion(A))
print("Lista ordenada por Burbuja")
print(ordenamiento_burbuja_optimizado2(A))
# Out:
# Lista original:  [237, 135, 129, 63, 204, 187, 56, 232, 238, 47, 108, 10, 90, 137, 232, 67, 175, 282, 189, 159, 280, 87, 137, 135, 238, 278, 259, 133, 231, 108, 53, 294, 224, 203, 111, 260, 148, 52, 194, 83, 16, 90, 281, 17, 233, 289, 271, 187, 96, 7, 201, 42, 247, 134, 137, 172, 279, 157, 165, 55, 192, 100, 16, 152, 271, 195, 164, 239, 237, 172, 284, 61, 276, 282, 101, 10, 296, 57, 111, 201, 83, 69, 46, 71, 223, 26, 285, 134, 258, 181, 49, 250, 150, 284, 289, 68, 8, 102, 145, 259, 160, 74, 208, 2, 136, 60, 224, 259, 291, 199, 238, 238, 281, 23, 258, 294, 14, 236, 208, 68, 12, 49, 206, 43, 88, 6, 233, 192, 27, 185, 99, 137, 87, 191, 265, 206, 101, 141, 69, 9, 93, 293, 123, 195, 271, 232, 189, 121, 271, 45, 259, 170, 164, 137, 205, 3, 176, 55, 273, 115, 79, 64, 74, 184, 270, 231, 29, 158, 242, 94, 78, 100, 48, 75, 217, 7, 117, 256, 216, 263, 158, 212, 298, 252, 8, 258, 110, 0, 249, 74, 145, 56, 113, 146, 265, 273, 154, 256, 141, 193, 292, 212, 3, 74, 98, 108, 211, 220, 71, 143, 148, 29, 245, 257, 24, 205, 203, 180, 59, 2, 75, 76, 96, 7, 289, 127, 216, 135, 163, 264, 151, 248, 103, 116, 86, 17, 87, 19, 7, 43, 114, 12, 260, 89, 140, 8, 83, 37, 70, 79, 73, 135, 292, 38, 94, 99, 92, 228, 7, 104, 142, 15, 94, 72, 260, 187, 183, 186, 224, 32, 72, 125, 186, 181, 77, 109, 64, 25, 130, 154, 209, 70, 173, 299, 215, 200, 102, 192, 160, 35, 209, 119, 298, 87, 271, 242, 248, 26, 85, 40]
228, 231, 231, 232, 232, 232, 233, 233, 236, 237, 237, 238, 238, 238, 238, 239, 242, 242, 245, 247, 248, 248, 249, 250, 252, 256, 256, 257, 258, 258, 258, 259, 259, 259, 259, 260, 260, 260, 263, 264, 265, 265, 270, 271, 271, 271, 271, 271, 273, 273, 276, 278, 279, 280, 281, 281, 282, 282, 284, 284, 285, 289, 289, 289, 291, 292, 292, 293, 294, 294, 296, 298, 298, 299]
# Lista ordenada por Burbuja
# [0, 2, 2, 3, 3, 6, 7, 7, 7, 7, 7, 8, 8, 8, 9, 10, 10, 12, 12, 14, 15, 16, 16, 17, 17, 19, 23, 24, 25, 26, 26, 27, 29, 29, 32, 35, 37, 38, 40, 42, 43, 43, 45, 46, 47, 48, 49, 49, 52, 53, 55, 55, 56, 56, 57, 59, 60, 61, 63, 64, 64, 67, 68, 68, 69, 69, 70, 70, 71, 71, 72, 72, 73, 74, 74, 74, 74, 75, 75, 76, 77, 78, 79, 79, 83, 83, 83, 85, 86, 87, 87, 87, 87, 88, 89, 90, 90, 92, 93, 94, 94, 94, 96, 96, 98, 99, 99, 100, 100, 101, 101, 102, 102, 103, 104, 108, 108, 108, 109, 110, 111, 111, 113, 114, 115, 116, 117, 119, 121, 123, 125, 127, 129, 130, 133, 134, 134, 135, 135, 135, 135, 136, 137, 137, 137, 137, 137, 140, 141, 141, 142, 143, 145, 145, 146, 148, 148, 150, 151, 152, 154, 154, 157, 158, 158, 159, 160, 160, 163, 164, 164, 165, 170, 172, 172, 173, 175, 176, 180, 181, 181, 183, 184, 185, 186, 186, 187, 187, 187, 189, 189, 191, 192, 192, 192, 193, 194, 195, 195, 199, 200, 201, 201, 203, 203, 204, 205, 205, 206, 206, 208, 208, 209, 209, 211, 212, 212, 215, 216, 216, 217, 220, 223, 224, 224, 224, 228, 231, 231, 232, 232, 232, 233, 233, 236, 237, 237, 238, 238, 238, 238, 239, 242, 242, 245, 247, 248, 248, 249, 250, 252, 256, 256, 257, 258, 258, 258, 259, 259, 259, 259, 260, 260, 260, 263, 264, 265, 265, 270, 271, 271, 271, 271, 271, 273, 273, 276, 278, 279, 280, 281, 281, 282, 282, 284, 284, 285, 289, 289, 289, 291, 292, 292, 293, 294, 294, 296, 298, 298, 299]

# %% [markdown]
# **Grafica de comparacion de los tiempos de ejecucion de los algoritmos de ordenamiento**

# %%
# tiempo de ejecucion de los algoritmos
t_quicksort = []
t_insercion = []
t_burbuja = []
# lista de n elementos aleatorios de 
n = []

for i in range(A[0], A[len(A)-1]):
    # lista de n elementos aleatorios de 

    n.append(i)
    lista = random.sample(range(1, 1001), i)
    
    start_time = time.time()
    quicksort(lista)
    t_quicksort.append(time.time() - start_time)
    #print("Lista ordenada por Insercion")
    start_time = time.time()
    ordenamiento_insercion(lista)
    t_insercion.append(time.time() - start_time)
    #print("Lista ordenada por Burbuja")
    start_time = time.time()
    ordenamiento_burbuja_optimizado2(lista)
    t_burbuja.append(time.time() - start_time)

plt.plot(n, t_quicksort, label = "Quicksort")
plt.plot(n, t_insercion, label = "Insercion")
plt.plot(n, t_burbuja, label = "Burbuja")
plt.xlabel('n')
plt.ylabel('tiempo')
plt.title('Comparacion de tiempos')
plt.legend()
plt.show()
