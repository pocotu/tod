# %%
import random
import time
import matplotlib.pyplot as plt

# %% [markdown]
# **Metodo Quicksort**

# %%
def quicksort(lista):
    if len(lista) <= 1:
        return lista
    else:
        pivot = lista[0]
        less = [x for x in lista[1:] if x <= pivot]
        greater = [x for x in lista[1:] if x > pivot]
        return quicksort(less) + [pivot] + quicksort(greater)

# %% [markdown]
# **Metodo Burbuja, el mas eficiente**

# %%
def ordenamiento_burbuja_optimizado2(lista):
    n = len(lista)
    intercambio = True
    iteracion = 0

    while (intercambio):
        intercambio = False
        for i in range(n - iteracion - 1):
            if (lista[i] > lista[i+1]):
                temp1 = lista[i]
                lista[i] = lista[i+1]
                lista[i+1] = temp1
                #lista[j], lista[j+1] = lista[j+1], lista[j]
                intercambio = True
        iteracion += 1
    #print("Numero de iteracion: ", iteracion)
    return lista

# %% [markdown]
# **Metodo Insercion**

# %%
def ordenamiento_insercion(A):
    n = len(A)

    for i in range(n):
        posicion = i
        aux = A[i]
        while (posicion > 0) and (A[posicion-1] > aux):
            A[posicion] = A[posicion-1]
            posicion = posicion - 1
        A[posicion] = aux
    return A

# %% [markdown]
# **Impresion de listas ordenadas**

# %%
numero = 300
A = []
for i in range(numero):
    A.append(random.randint(0, numero))

print("Lista original: ", A)
print("Lista ordenada por Quicksort")
print(quicksort(A))
print("Lista ordenada por Insercion")
print(ordenamiento_insercion(A))
print("Lista ordenada por Burbuja")
print(ordenamiento_burbuja_optimizado2(A))
# Out:
# Lista original:  [272, 200, 137, 222, 134, 221, 245, 145, 273, 204, 34, 196, 38, 51, 260, 207, 234, 277, 104, 214, 177, 243, 243, 8, 111, 133, 34, 112, 52, 157, 106, 226, 247, 245, 48, 43, 222, 31, 38, 68, 246, 81, 74, 59, 93, 116, 268, 279, 290, 69, 62, 17, 181, 225, 41, 295, 54, 44, 41, 108, 153, 83, 81, 101, 1, 96, 189, 232, 57, 22, 275, 183, 16, 256, 57, 133, 140, 108, 222, 188, 27, 34, 86, 12, 105, 238, 216, 105, 294, 219, 116, 206, 82, 117, 213, 27, 162, 117, 207, 179, 237, 131, 205, 52, 73, 129, 214, 93, 43, 42, 148, 257, 286, 128, 165, 295, 297, 266, 252, 196, 279, 98, 154, 245, 106, 202, 60, 248, 144, 127, 219, 76, 145, 270, 59, 51, 23, 249, 82, 90, 258, 18, 84, 240, 85, 69, 271, 37, 2, 66, 92, 47, 25, 67, 71, 286, 17, 117, 31, 287, 114, 193, 10, 184, 85, 141, 54, 42, 177, 290, 159, 224, 50, 51, 61, 251, 245, 55, 119, 79, 197, 4, 31, 267, 217, 105, 169, 243, 144, 267, 254, 240, 161, 252, 205, 108, 56, 66, 12, 160, 174, 141, 121, 138, 38, 39, 142, 135, 1, 86, 158, 180, 122, 136, 188, 241, 95, 234, 239, 295, 44, 173, 190, 126, 66, 161, 56, 61, 129, 11, 34, 253, 15, 17, 31, 27, 248, 261, 206, 57, 30, 73, 155, 239, 34, 265, 274, 2, 10, 156, 131, 5, 46, 246, 82, 100, 152, 19, 258, 41, 165, 202, 68, 258, 112, 96, 130, 32, 180, 128, 153, 117, 118, 288, 109, 205, 102, 249, 84, 270, 219, 116, 258, 283, 200, 259, 100, 229, 70, 30, 30, 176, 214, 8, 276, 30, 249, 290, 213, 103]
 222, 224, 225, 226, 229, 232, 234, 234, 237, 238, 239, 239, 240, 240, 241, 243, 243, 243, 245, 245, 245, 245, 246, 246, 247, 248, 248, 249, 249, 249, 251, 252, 252, 253, 254, 256, 257, 258, 258, 258, 258, 259, 260, 261, 265, 266, 267, 267, 268, 270, 270, 271, 272, 273, 274, 275, 276, 277, 279, 279, 283, 286, 286, 287, 288, 290, 290, 290, 294, 295, 295, 295, 297]
# Lista ordenada por Burbuja
# [1, 1, 2, 2, 4, 5, 8, 8, 10, 10, 11, 12, 12, 15, 16, 17, 17, 17, 18, 19, 22, 23, 25, 27, 27, 27, 30, 30, 30, 30, 31, 31, 31, 31, 32, 34, 34, 34, 34, 34, 37, 38, 38, 38, 39, 41, 41, 41, 42, 42, 43, 43, 44, 44, 46, 47, 48, 50, 51, 51, 51, 52, 52, 54, 54, 55, 56, 56, 57, 57, 57, 59, 59, 60, 61, 61, 62, 66, 66, 66, 67, 68, 68, 69, 69, 70, 71, 73, 73, 74, 76, 79, 81, 81, 82, 82, 82, 83, 84, 84, 85, 85, 86, 86, 90, 92, 93, 93, 95, 96, 96, 98, 100, 100, 101, 102, 103, 104, 105, 105, 105, 106, 106, 108, 108, 108, 109, 111, 112, 112, 114, 116, 116, 116, 117, 117, 117, 117, 118, 119, 121, 122, 126, 127, 128, 128, 129, 129, 130, 131, 131, 133, 133, 134, 135, 136, 137, 138, 140, 141, 141, 142, 144, 144, 145, 145, 148, 152, 153, 153, 154, 155, 156, 157, 158, 159, 160, 161, 161, 162, 165, 165, 169, 173, 174, 176, 177, 177, 179, 180, 180, 181, 183, 184, 188, 188, 189, 190, 193, 196, 196, 197, 200, 200, 202, 202, 204, 205, 205, 205, 206, 206, 207, 207, 213, 213, 214, 214, 214, 216, 217, 219, 219, 219, 221, 222, 222, 222, 224, 225, 226, 229, 232, 234, 234, 237, 238, 239, 239, 240, 240, 241, 243, 243, 243, 245, 245, 245, 245, 246, 246, 247, 248, 248, 249, 249, 249, 251, 252, 252, 253, 254, 256, 257, 258, 258, 258, 258, 259, 260, 261, 265, 266, 267, 267, 268, 270, 270, 271, 272, 273, 274, 275, 276, 277, 279, 279, 283, 286, 286, 287, 288, 290, 290, 290, 294, 295, 295, 295, 297]

# %% [markdown]
# **Grafica de comparacion de los tiempos de ejecucion de los algoritmos de ordenamiento**

# %%
# tiempo de ejecucion de los algoritmos
t_quicksort = []
t_insercion = []
t_burbuja = []
# lista de n elementos aleatorios de 
n = []

for i in range(A[0], A[len(A)-1]+1):
    # lista de n elementos aleatorios de 

    n.append(i)
    lista = random.sample(range(1, numero+1), i)
    
    start_time = time.time()
    quicksort(lista)
    t_quicksort.append(time.time() - start_time)
    #print("Lista ordenada por Insercion")
    start_time = time.time()
    ordenamiento_insercion(lista)
    t_insercion.append(time.time() - start_time)
    #print("Lista ordenada por Burbuja")
    start_time = time.time()
    ordenamiento_burbuja_optimizado2(lista)
    t_burbuja.append(time.time() - start_time)

plt.plot(n, t_quicksort, label = "Quicksort")
plt.plot(n, t_insercion, label = "Insercion")
plt.plot(n, t_burbuja, label = "Burbuja")
plt.xlabel('n')
plt.ylabel('tiempo')
plt.title('Comparacion de tiempos')
plt.legend()
plt.show()
