# %% [markdown]
# # dibujar un corazon

# %%
def corazon(n):
    for i in range(n):
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))
        print(" "*(n-i-1)+"*")
        print(" "*(n-i-1)+"*")
        print("*"*(i+1))

corazon(10)
# corazon(10)
# Out:
# *
#          *
#          *
# *
#          *
#          *
# *
#          *
#          *
# *
#          *
#          *
# *
#          *
#          *
# *
#          *
#          *
# *
#          *
#          *
# *
#          *
#          *
# *
#          *
#          *
# *
#          *
#          *
# *
#          *
#          *
# *
# **
#         *
#         *
# **
#         *
#         *
# **
#         *
#         *
# **
#         *
#         *
# **
#         *
#         *
# **
#         *
#         *
# **
#         *
#         *
# **
#         *
#         *
# **
#         *
#         *
# **
#         *
#         *
# **
#         *
#         *
# **
# ***
#        *
#        *
# ***
#        *
#        *
# ***
#        *
#        *
# ***
#        *
#        *
# ***
#        *
#        *
# ***
#        *
#        *
# ***
#        *
#        *
# ***
#        *
#        *
# ***
#        *
#        *
# ***
#        *
#        *
# ***
#        *
#        *
# ***
# ****
#       *
#       *
# ...
