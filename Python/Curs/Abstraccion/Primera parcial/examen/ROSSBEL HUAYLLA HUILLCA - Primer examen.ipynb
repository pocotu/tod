# %% [markdown]
# #INFORMACIÓN GENERAL

# %% [markdown]
# UNIVERSIDAD NACIONAL DE SAN ANTONIO ABAD DEL CUSCO
#
# ESCUELA PROFESIONAL DE INGENIERÍA INFORMÁTICA Y DE SISTEMAS
#
# ABSTRACCIÓN DE DATOS Y OBJETOS
#
# PRIMER EXAMEN

# %% [markdown]
# ##Pregunta 1

# %% [markdown]
# Frente a los rumores de una cuarta ola de la pandemia, la Dirección Regional de Salud del Cusco desea implementar acciones de prevención. Para lo cual, se tiene la información del número de contagiados COVID de cada distrito de cada una de las provincias del departamento del Cusco, correspondientes a los meses de mayo y junio. Se implementa una acción de prevención en aquellos distritos que tengan más de 100 contagiados en los dos meses o que el número de contagiados en el mes de junio sea 2 veces más que los del mes de mayo. Escribir un programa modular que determine en cúantos distritos de una determinada provincia se debe implementar acciones de prevención.

# %%
def datos(Provincia, Distrito):
    T_Provincia = []
    T_Distrito = []
    T_infectados = []
    Provincia = input("Ingrese la provincia: ")
    T_Provincia.append(Provincia)
    Distrito = input("Ingrese el distrito: ")
    T_Distrito.append(Distrito)
    infectados = int(input("Ingrese el número de contagiados: "))
    T_infectados.append(infectados)
    if infectados > 100:
        print("Se debe implementar acciones de prevención")
    elif infectados > 200:
        print("Se debe implementar acciones de prevención")
    else:
        print("No se debe implementar acciones de prevención")
    return T_Provincia, T_Distrito, T_infectados

#Provincia = input("Ingrese la provincia: ")
#Distrito = input("Ingrese el distrito: ")
#infectados = int(input("Ingrese el número de contagiados: "))

# %% [markdown]
# ##Pregunta 2

# %% [markdown]
# Se considera que dos números enteros positivos son enemigos, si ambos números están formados por dígitos distintos; es decir, que ningún dígito del primer número está presente en el segundo. Escribir un programa modular que determine si dos números enteros positivos son o no enemigos.
#
# ![image.png](data:image/png;base64,...)

# %%
def Agregar_A_Lista(num1, num2):
    nume1 = []
    nume2 = []
    for i in num1:
        nume1.append(int(i))
    for i in num2:
        nume2.append(int(i))
    print(nume1, nume2)
    
def comparar(nume1, nume2):
    if set(nume1) == set(nume2):
        print("son enmigos")

num1 = input("Ingrese el número 1: ")
num2 = input("Ingrese el número 2: ")
Agregar_A_Lista(num1, num2)

        
       
#def main():
#    num1 = int(input("Ingrese el primer número: "))
#    num2 = int(input("Ingrese el segundo número: "))
#    for i in num1:
#        for j in num2:
#            if i == j:
#                print("Los números son enemigos")
#            else:
#                print("Los números no son enemigos")
# Out:
# [2, 3, 4] [2, 3, 6]
