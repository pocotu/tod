# %%
import random
import time
import matplotlib.pyplot as plt

# %% [markdown]
# **Metodo Quicksort**

# %%
def quicksort(lista):
    if len(lista) <= 1:
        return lista
    else:
        pivot = lista[0]
        less = [x for x in lista[1:] if x <= pivot]
        greater = [x for x in lista[1:] if x > pivot]
        return quicksort(less) + [pivot] + quicksort(greater)

# %% [markdown]
# **Metodo Burbuja, el mas eficiente**

# %%
def ordenamiento_burbuja_optimizado2(lista):
    n = len(lista)
    intercambio = True
    iteracion = 0

    while (intercambio):
        intercambio = False
        for i in range(n - iteracion - 1):
            if (lista[i] > lista[i+1]):
                temp1 = lista[i]
                lista[i] = lista[i+1]
                lista[i+1] = temp1
                #lista[j], lista[j+1] = lista[j+1], lista[j]
                intercambio = True
        iteracion += 1
    #print("Numero de iteracion: ", iteracion)
    return lista

# %% [markdown]
# **Metodo Insercion**

# %%
def ordenamiento_insercion(A):
    n = len(A)

    for i in range(n):
        posicion = i
        aux = A[i]
        while (posicion > 0) and (A[posicion-1] > aux):
            A[posicion] = A[posicion-1]
            posicion = posicion - 1
        A[posicion] = aux
    return A

# %% [markdown]
# **Impresion de listas ordenadas**

# %%
numero = 300
A = []
for i in range(numero):
    A.append(random.randint(0, numero))

print("Lista original: ", A)
print("Lista ordenada por Quicksort")
print(quicksort(A))
print("Lista ordenada por Insercion")
print(ordenamiento_insercion(A))
print("Lista ordenada por Burbuja")
print(ordenamiento_burbuja_optimizado2(A))
# Out:
# Lista original:  [152, 85, 300, 142, 238, 160, 194, 5, 198, 206, 256, 3, 266, 295, 188, 36, 108, 9, 192, 153, 257, 171, 153, 90, 205, 94, 7, 198, 137, 132, 4, 195, 186, 209, 87, 157, 2, 9, 208, 281, 127, 213, 261, 102, 176, 145, 176, 284, 130, 72, 20, 37, 118, 38, 241, 32, 19, 62, 143, 246, 187, 148, 228, 115, 10, 229, 170, 167, 144, 250, 278, 249, 121, 105, 110, 42, 17, 272, 69, 221, 6, 227, 258, 104, 96, 2, 27, 78, 185, 175, 12, 60, 36, 192, 19, 131, 162, 93, 72, 3, 101, 270, 25, 68, 14, 209, 125, 114, 44, 81, 87, 160, 227, 203, 132, 75, 259, 187, 274, 23, 10, 63, 113, 8, 112, 93, 257, 216, 97, 182, 65, 103, 205, 165, 273, 44, 186, 103, 103, 219, 230, 250, 206, 194, 178, 273, 276, 75, 116, 106, 152, 233, 23, 245, 217, 264, 47, 39, 43, 290, 107, 216, 201, 202, 201, 25, 126, 202, 204, 67, 160, 15, 3, 17, 46, 170, 194, 292, 176, 176, 48, 200, 153, 77, 258, 72, 242, 139, 147, 108, 245, 252, 19, 210, 173, 104, 25, 13, 189, 279, 60, 116, 97, 22, 64, 212, 151, 67, 61, 73, 115, 80, 269, 132, 63, 247, 224, 255, 120, 234, 33, 249, 26, 15, 149, 273, 64, 86, 83, 118, 232, 204, 288, 3, 102, 246, 212, 3, 37, 62, 64, 299, 164, 85, 132, 189, 284, 31, 172, 30, 78, 270, 75, 110, 295, 61, 270, 300, 196, 103, 288, 55, 53, 69, 23, 100, 98, 176, 12, 199, 5, 190, 171, 121, 82, 57, 98, 269, 123, 215, 250, 250, 101, 8, 258, 198, 130, 195, 265, 25, 267, 88, 91, 176, 270, 192, 250, 40, 221, 165]
, 209, 209, 210, 212, 212, 213, 215, 216, 216, 217, 219, 221, 221, 224, 227, 227, 228, 229, 230, 232, 233, 234, 238, 241, 242, 245, 245, 246, 246, 247, 249, 249, 250, 250, 250, 250, 250, 252, 255, 256, 257, 257, 258, 258, 258, 259, 261, 264, 265, 266, 267, 269, 269, 270, 270, 270, 270, 272, 273, 273, 273, 274, 276, 278, 279, 281, 284, 284, 288, 288, 290, 292, 295, 295, 299, 300, 300]
# Lista ordenada por Burbuja
# [2, 2, 3, 3, 3, 3, 3, 4, 5, 5, 6, 7, 8, 8, 9, 9, 10, 10, 12, 12, 13, 14, 15, 15, 17, 17, 19, 19, 19, 20, 22, 23, 23, 23, 25, 25, 25, 25, 26, 27, 30, 31, 32, 33, 36, 36, 37, 37, 38, 39, 40, 42, 43, 44, 44, 46, 47, 48, 53, 55, 57, 60, 60, 61, 61, 62, 62, 63, 63, 64, 64, 64, 65, 67, 67, 68, 69, 69, 72, 72, 72, 73, 75, 75, 75, 77, 78, 78, 80, 81, 82, 83, 85, 85, 86, 87, 87, 88, 90, 91, 93, 93, 94, 96, 97, 97, 98, 98, 100, 101, 101, 102, 102, 103, 103, 103, 103, 104, 104, 105, 106, 107, 108, 108, 110, 110, 112, 113, 114, 115, 115, 116, 116, 118, 118, 120, 121, 121, 123, 125, 126, 127, 130, 130, 131, 132, 132, 132, 132, 137, 139, 142, 143, 144, 145, 147, 148, 149, 151, 152, 152, 153, 153, 153, 157, 160, 160, 160, 162, 164, 165, 165, 167, 170, 170, 171, 171, 172, 173, 175, 176, 176, 176, 176, 176, 176, 178, 182, 185, 186, 186, 187, 187, 188, 189, 189, 190, 192, 192, 192, 194, 194, 194, 195, 195, 196, 198, 198, 198, 199, 200, 201, 201, 202, 202, 203, 204, 204, 205, 205, 206, 206, 208, 209, 209, 210, 212, 212, 213, 215, 216, 216, 217, 219, 221, 221, 224, 227, 227, 228, 229, 230, 232, 233, 234, 238, 241, 242, 245, 245, 246, 246, 247, 249, 249, 250, 250, 250, 250, 250, 252, 255, 256, 257, 257, 258, 258, 258, 259, 261, 264, 265, 266, 267, 269, 269, 270, 270, 270, 270, 272, 273, 273, 273, 274, 276, 278, 279, 281, 284, 284, 288, 288, 290, 292, 295, 295, 299, 300, 300]

# %% [markdown]
# **Grafica de comparacion de los tiempos de ejecucion de los algoritmos de ordenamiento**

# %%
# tiempo de ejecucion de los algoritmos
t_quicksort = []
t_insercion = []
t_burbuja = []
# lista de n elementos aleatorios
n = []

for i in range(A[0], A[len(A)-1]+1):
    n.append(i)
    lista = random.sample(range(1, numero+1), i)
    
    start_time = time.time()
    quicksort(lista)
    t_quicksort.append(time.time() - start_time)
    #print("Lista ordenada por Insercion")
    start_time = time.time()
    ordenamiento_insercion(lista)
    t_insercion.append(time.time() - start_time)
    #print("Lista ordenada por Burbuja")
    start_time = time.time()
    ordenamiento_burbuja_optimizado2(lista)
    t_burbuja.append(time.time() - start_time)

plt.plot(n, t_quicksort, label = "Quicksort")
plt.plot(n, t_insercion, label = "Insercion")
plt.plot(n, t_burbuja, label = "Burbuja")
plt.xlabel('n')
plt.ylabel('tiempo')
plt.title('Comparacion de tiempos')
plt.legend()
plt.show()
